# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushpaliwal1920/Deep_Learning/blob/main/39_Embedding_demo_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras.datasets import imdb # preprocessed data
from keras import Sequential
from tensorflow.keras.layers import Dense , Embedding , Flatten

# %%
docs = [ 'go india',
         'india india',
         'hip hip hurray',
         'jeetega bhai jeetega india jeetega',
         'bharat mata ki jai',
         'kohli kohli',
         'sachin sachin',
         'dhoni dhoni',
         'modi ji ki jai',
         'inquilab jindabad']

# %%
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()

# %%
tokenizer.fit_on_texts(docs)

# %%
len(tokenizer.word_index)
# Out:
# 17

# %%
sequences = tokenizer.texts_to_sequences(docs)
sequences
# Out:
# [[9, 1],
#  [1, 1],
#  [3, 3, 10],
#  [2, 11, 2, 1, 2],
#  [12, 13, 4, 5],
#  [6, 6],
#  [7, 7],
#  [8, 8],
#  [14, 15, 4, 5],
#  [16, 17]]

# %%
# padding

from tensorflow.keras.utils import pad_sequences

sequences = pad_sequences(sequences , padding = 'post')
sequences
# Out:
# array([[ 9,  1,  0,  0,  0],
#        [ 1,  1,  0,  0,  0],
#        [ 3,  3, 10,  0,  0],
#        [ 2, 11,  2,  1,  2],
#        [12, 13,  4,  5,  0],
#        [ 6,  6,  0,  0,  0],
#        [ 7,  7,  0,  0,  0],
#        [ 8,  8,  0,  0,  0],
#        [14, 15,  4,  5,  0],
#        [16, 17,  0,  0,  0]], dtype=int32)

# %%
# Embedding layer : 17 is the total vocab length(unique words) , output_dims = vector dimensions/representation , input_length = input words

model = Sequential()
model.add(Embedding(17,output_dim=2,input_shape=(5,)))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:103: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_5 (Embedding)         │ (None, 5, 2)           │            34 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 34 (136.00 B)
#  Trainable params: 34 (136.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile('adam' , 'accuracy')

# %%
pred = model.predict(sequences)
print(pred)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step
# [[[-0.00552058  0.01565825]
#   [-0.00407841 -0.03103628]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]]
#
#  [[-0.00407841 -0.03103628]
#   [-0.00407841 -0.03103628]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]]
#
#  [[ 0.03958383 -0.01276114]
#   [ 0.03958383 -0.01276114]
#   [-0.0464445   0.04223371]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]]
#
#  [[-0.04174334 -0.00057866]
#   [-0.02649428 -0.00433661]
#   [-0.04174334 -0.00057866]
#   [-0.00407841 -0.03103628]
#   [-0.04174334 -0.00057866]]
#
#  [[ 0.02816365  0.00299356]
#   [ 0.03896651 -0.01086608]
#   [ 0.02880609  0.04534136]
#   [ 0.03725494 -0.04270367]
#   [ 0.00164288 -0.02826941]]
#
#  [[-0.04604549 -0.01100067]
#   [-0.04604549 -0.01100067]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]
#   [ 0.00164288 -0.02826941]]
#
#  [[ 0.00364982 -0.04181962]
# ...
