# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushpaliwal1920/Deep_Learning/blob/main/36_SimpleRnn_architecture_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense , SimpleRNN

# %%
model = Sequential()

model.add(SimpleRNN(3,input_shape = (4,5)))
model.add(Dense(1,activation = 'sigmoid'))

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn_1 (SimpleRNN)        │ (None, 3)              │            27 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │             4 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 31 (124.00 B)
#  Trainable params: 31 (124.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
print(model.get_weights()[0].shape)
model.get_weights()[0]
# Out:
# (5, 3)
# array([[-0.16994917,  0.27655512, -0.08046782],
#        [ 0.8640383 , -0.83832574,  0.2883373 ],
#        [-0.01691252,  0.38921613, -0.6183735 ],
#        [ 0.00324249,  0.06740981,  0.24827462],
#        [-0.08303475,  0.32596642,  0.27469164]], dtype=float32)

# %%
print(model.get_weights()[1].shape)
model.get_weights()[1]
# Out:
# (3, 3)
# array([[-0.6054257 , -0.78930867, -0.1022323 ],
#        [ 0.34538078, -0.14482357, -0.9272207 ],
#        [-0.7170577 ,  0.59667236, -0.36029196]], dtype=float32)

# %%
print(model.get_weights()[2].shape)
model.get_weights()[2]
# Out:
# (3,)
# array([0., 0., 0.], dtype=float32)

# %%
print(model.get_weights()[3].shape)
model.get_weights()[3]
# Out:
# (3, 1)
# array([[ 0.8298904 ],
#        [ 0.9409858 ],
#        [-0.54306465]], dtype=float32)

# %%
print(model.get_weights()[4].shape)
model.get_weights()[4]
# Out:
# (1,)
# array([0.], dtype=float32)
